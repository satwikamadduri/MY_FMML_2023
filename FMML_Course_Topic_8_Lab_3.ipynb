# %% [markdown]
# <a href="https://colab.research.google.com/github/satwikamadduri/MY_FMML_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-04 17:25:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  84.6MB/s    in 0.8s
#
# 2024-04-04 17:25:42 (84.6 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 31142  1802.04914v2  In this paper, we introduce a web-scale genera...    cs
# 22578  1701.06508v2  Clustering is a central approach for unsupervi...  stat
# 904    1702.04782v2  Generative adversarial networks (GANs) transfo...    cs
# 10979   1307.1493v2  Dropout and other feature noising schemes cont...  stat
# 5775    1206.4646v1  Stochastic neighbor embedding (SNE) and relate...    cs
# ...             ...                                                ...   ...
# 23063  1803.03432v1  We propose practical extensions to Bayesian op...  stat
# 14737   1201.1192v1  A formal theory based on a binary operator of ...    cs
# 1130   1712.04118v1  Principal component analysis (PCA) is largely ...    cs
# 30980  1802.00179v1  Recent years, compressive sensing (CS) has imp...    cs
# 40074  1710.05027v1  Fingerprint verification is an important bio-m...    cs
#
#                                                    title  year  \
# 31142         Web-Scale Responsive Visual Search at Bing  2018
# 22578  The Impact of Random Models on Clustering Simi...  2017
# 904    Precise Recovery of Latent Vectors from Genera...  2017
# 10979        Dropout Training as Adaptive Regularization  2013
# 5775   Partial-Hessian Strategies for Fast Learning o...  2012
# ...                                                  ...   ...
# 23063         Bayesian Optimization for Dynamic Problems  2018
# 14737  Formalization of semantic network of image con...  2012
# 1130       Neural Component Analysis for Fault Detection  2017
# 30980  Full Image Recover for Block-Based Compressive...  2018
# 40074  Real time ridge orientation estimation for fin...  2017
#
#                                                 keywords
# 31142  [introduce, microsoft, accommodates, thousands...
# 22578  [clustering, unsupervised, clustering, fundame...
# 904    [generative, adversarial, transform, plausible...
# 10979  [overfitting, artificially, corrupting, genera...
# 5775   [stochastic, embedding, nonlinear, algorithms,...
# ...                                                  ...
# 23063  [practical, extensions, optimization, objectiv...
# 14737  [directional, associative, constructed, unders...
# 1130   [principal, component, monitoring, developed, ...
# 30980  [compressive, application, technology, conveni...
# 40074  [fingerprint, verification, important, techniq...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 31142    [introduce, microsoft, accommodates, thousands...
# 22578    [clustering, unsupervised, clustering, fundame...
# 904      [generative, adversarial, transform, plausible...
# 10979    [overfitting, artificially, corrupting, genera...
# 5775     [stochastic, embedding, nonlinear, algorithms,...
#                                ...
# 3579     [attracted, significant, attention, simultaneo...
# 15490    [societies, developed, languages, bangalore, h...
# 6636     [background, approaches, biomedical, implement...
# 33479    [artificial, intrusion, detection, appealing, ...
# 23027    [simultaneously, prediction, generalization, p...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8746 words.
# Out of those 4597 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f4ca8295-4541-45ae-9b69-d2d64587ccdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4ca8295-4541-45ae-9b69-d2d64587ccdd")) {                    Plotly.newPlot(                        "f4ca8295-4541-45ae-9b69-d2d64587ccdd",                        [{"x":["distributed","microsoft","quantitative","heterogeneous","framework","challenges","accommodates","scalability","relevance","applications","thousands","computing","qualitative","responsive","experiments","introduce","permutation","illustrated","expression","demonstrate","necessarily","distribution","consensus","different","reference","ensembles","clusterings","carefully","recognition","synthetic","unsupervised","comparisons","consequences","evaluation","clustering","prevailing","handwriting","justified","quantitatively","corrected","similarity","assumption","establish","fundamental","stochastic","generated","additional","transform","precisely","technique","projecting","plausible","generative","encodings","formulation","adversarial","generally","supervised","corrupting","equivalent","unlabeled","overfitting","regularized","consistently","regularizer","generalized","viewpoint","algorithm","classification","performance","artificially","information","repeatedly","improving","regularization","connection","representations","laplacians","nonlinear","embedding","optimization","magnitude","algorithms","notoriously","characterize","embeddings","empirically","applicable","strategies","dimensional","convergence","sentences","processing","previously","convolutional","descriptive","descriptions","captioning","representation","description","described","comparable","considerably","statistics","generating","interesting","constraint","approaches","exponential","theoretical","graphical","computational","representational","complexity","inference","importance","perspective","limitations","probabilistic","empirical","advantages","surveillance","candidate","benchmark","significant","intriguingly","improvement","specifically","techniques","commercial","detection","developed","localization","particular","multiagent","functions","traditional","collaborative","processes","continuous","structure","formulated","arguments","naturally","approximate","discretization","potential","approximation","formulate","adequately","efficiently","represented","variables","promising","systematically","literature","furthermore","retrieval","increasing","challenging","incidents","irrelevant","important","infringement","addressed","evaluated","densities","homomorphism","expensive","autoimmune","intuitive","guarantee","computable","theoretically","distinguish","competitive","difficult","subgraphs","classifier","projection","intermittent","aggregation","decomposition","significantly","characterisation","individuals","groupings","components","transient","appropriate","characterized","synthetically","correspond","decreases","motivated","outperforms","individual","aggregate","decomposed","populations"],"y":[108,9,67,38,550,110,1,38,37,424,22,139,57,2,600,321,13,16,47,578,20,214,16,749,60,18,4,36,373,131,154,34,8,252,161,5,9,6,25,6,139,64,45,89,137,189,128,71,22,256,6,25,123,12,98,112,69,197,3,68,46,23,39,36,24,57,33,842,449,829,8,689,10,102,92,39,211,2,61,115,345,71,598,6,43,80,73,50,94,173,141,53,307,106,375,9,26,16,352,65,59,78,27,57,102,71,72,450,43,151,39,303,7,237,202,83,75,66,150,138,78,36,60,226,210,2,137,174,417,25,377,207,65,271,5,219,184,38,113,99,331,36,24,53,113,6,170,114,58,5,148,88,109,128,33,131,180,97,98,280,4,15,377,2,45,132,16,2,81,2,30,37,8,37,36,122,151,5,130,50,2,24,70,282,3,46,1,99,6,78,40,7,37,16,59,258,120,18,15,9],"type":"bar"},{"x":["distributed","microsoft","quantitative","heterogeneous","framew ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4597,), (4597, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Specialising</span> <span style=''>Word</span> <span style=''>Vectors</span> <span style=''>for</span> <span style=''>Lexical</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>Entailment</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>LEAR</span> <span style=''>(Lexical</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>Entailment</span> <span style=''>Attract</span> <span style=''>Repel)</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>post</span> <span style='background-color:rgba(0, 255, 0, 0.4413145539906103);'>processing</span> <span style=''>method</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>any</span> <span style=''>input</span> <span style=''>word</span> <span style=''>vector</span> <span style=''>space</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>emphasise</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>asymmetric</span> <span style=''>relation</span> <span style=''>of</span> <span style=''>lexical</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>entailment</span> <span style=''>(LE)</span> <span style=''>also</span> <span style=''>known</span> <span style=''>as</span> <span style=''>the</span> <span style=''>is</span> <span style=''>a</span> <span style=''>or</span> <span style=''>hyponymy</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>hypernymy</span> <span style=''>relation</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666665);'>injecting</span> <span style=''>external</span> <span style='background-color:rgba(0, 255, 0, 0.9154929577464788);'>linguistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>(eg</span> <span style=''>WordNet</span> <span style=''>links)</span> <span style=''>into</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>vector</span> <span style=''>space</span> <span style=''>the</span> <span style=''>LE</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>specialisation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>brings</span> <span style=''>true</span> <span style=''>hyponymy</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>hypernymy</span> <span style=''>pairs</span> <span style=''>closer</span> <span style=''>together</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>space</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>asymmetric</span> <span style=''>distance</span> <span style=''>measure</span> <span style=''>adjusts</span> <span style=''>the</span> <span style=''>norms</span> <span style=''>of</span> <span style=''>word</span> <span style=''>vectors</span> <span style=''>to</span> <span style=''>reflect</span> <span style=''>the</span> <span style=''>actual</span> <span style=''>WordNet</span> <span style=''>style</span> <span style='background-color:rgba(0, 255, 0, 0.3584905660377358);'>hierarchy</span> <span style=''>of</span> <span style=''>concepts</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Simultaneously</span> <span style=''>a</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>enforces</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarity</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>symmetric</span> <span style=''>cosine</span> <span style=''>distance</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Deep</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(GPs)</span> <span style=''>are</span> <span style=''>a</span> <span style=''>good</span> <span style=''>choice</span> <span style=''>for</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>as</span> <span style=''>they</span> <span style=''>are</span> <span style=''>flexible</span> <span style=''>robust</span> <span style=''>to</span> <span style=''>over</span> <span style=''>fitting</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibrated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>Deep</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(DGPs)</span> <span style=''>are</span> <span style=''>multi</span> <span style=''>layer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalisations</span> <span style=''>of</span> <span style=''>GPs</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>these</span> <span style=''>models</span> <span style=''>has</span> <span style=''>proved</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>Existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>DGP</span> <span style=''>models</span> <span style=''>assume</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posteriors</span> <span style=''>that</span> <span style=''>force</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>between</span> <span style=''>the</span> <span style=''>layers</span> <span style=''>and</span> <span style=''>do</span> <span style=''>not</span> <span style=''>work</span> <span style=''>well</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>does</span> <span style=''>not</span> <span style=''>force</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>between</span> <span style=''>layers</span> <span style=''>With</span> <span style=''>our</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>a</span> <span style=''>DGP</span> <span style=''>model</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>on</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Filtrated</span> <span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algebraic</span> <span style=''>Subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Algebraic</span> <span style=''>Subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>(ASC)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>elegant</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>fitting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiation</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>noiseless</span> <span style=''>data</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>union</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>In</span> <span style=''>practice</span> <span style=''>however</span> <span style=''>ASC</span> <span style=''>is</span> <span style=''>limited</span> <span style=''>to</span> <span style=''>equi</span> <span style='background-color:rgba(255, 0, 0, 0.35687732342007433);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>because</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimension</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algebraic</span> <span style=''>methods</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>noise</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>new</span> <span style=''>ASC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>can</span> <span style=''>handle</span> <span style=''>noisy</span> <span style=''>data</span> <span style=''>drawn</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>The</span> <span style=''>key</span> <span style=''>ideas</span> <span style=''>are</span> <span style=''>(1)</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>at</span> <span style=''>each</span> <span style=''>point</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decreasing</span> <span style=''>sequence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style='background-color:rgba(0, 255, 0, 0.4623655913978494);'>containing</span> <span style=''>the</span> <span style=''>subspace</span> <span style=''>passing</span> <span style=''>through</span> <span style=''>that</span> <span style=''>point</span> <span style=''>(2)</span> <span style=''>to</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distances</span> <span style=''>from</span> <span style=''>any</span> <span style=''>other</span> <span style=''>point</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalization</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exploration</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Randomized</span> <span style=''>Value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomized</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>(RLSVI)</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>explore</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>via</span> <span style=''>linearly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameterized</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>We</span> <span style=''>explain</span> <span style=''>why</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>that</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>or</span> <span style=''>epsilon</span> <span style=''>greedy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>can</span> <span style=''>be</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inefficient</span> <span style=''>and</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>results</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>dramatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>gains</span> <span style=''>enjoyed</span> <span style=''>by</span> <span style=''>RLSVI</span> <span style=''>Further</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>an</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>regret</span> <span style=''>of</span> <span style=''>RLSVI</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrates</span> <span style=''>near</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimality</span> <span style=''>in</span> <span style=''>a</span> <span style=''>tabula</span> <span style=''>rasa</span> <span style=''>learning</span> <span style=''>context</span> <span style=''>More</span> <span style=''>broadly</span> <span style=''>our</span> <span style=''>results</span> <span style=''>suggest</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomized</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>offer</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>promising</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>tackling</span> <span style=''>a</span> <span style=''>critical</span> <span style='background-color:rgba(255, 0,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09064748201438849)
# 	representation (0.12661870503597122)
# 	segmentation (0.06690647482014389)
# 	processing (0.110431654676259)
# 	architecture (0.09172661870503597)
# 	information (0.24784172661870504)
# 	detection (0.1356115107913669)
# 	convolutional (0.13489208633093525)
# 	recognition (0.13417266187050358)
# 	different (0.2694244604316547)
#
# Some Statistics words are:
# 	variational (0.09752475247524753)
# 	statistical (0.14405940594059405)
# 	estimation (0.16485148514851486)
# 	algorithm (0.3935643564356436)
# 	variables (0.1311881188118812)
# 	theoretical (0.15148514851485148)
# 	distribution (0.18465346534653465)
# 	inference (0.1905940594059406)
# 	dimensional (0.1806930693069307)
# 	regression (0.1801980198019802)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a7c58121-4dae-4c61-b712-7560f9c91db5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7c58121-4dae-4c61-b712-7560f9c91db5")) {                    Plotly.newPlot(                        "a7c58121-4dae-4c61-b712-7560f9c91db5",                        [{"x":["distributed","microsoft","quantitative","heterogeneous","framework","challenges","accommodates","scalability","relevance","applications","thousands","computing","qualitative","responsive","experiments","introduce","permutation","illustrated","expression","demonstrate","necessarily","distribution","consensus","different","reference","ensembles","clusterings","carefully","recognition","synthetic","unsupervised","comparisons","consequences","evaluation","clustering","prevailing","handwriting","justified","quantitatively","corrected","similarity","assumption","establish","fundamental","stochastic","generated","additional","transform","precisely","technique","projecting","plausible","generative","encodings","formulation","adversarial","generally","supervised","corrupting","equivalent","unlabeled","overfitting","regularized","consistently","regularizer","generalized","viewpoint","algorithm","classification","performance","artificially","information","repeatedly","improving","regularization","connection","representations","laplacians","nonlinear","embedding","optimization","magnitude","algorithms","notoriously","characterize","embeddings","empirically","applicable","strategies","dimensional","convergence","sentences","processing","previously","convolutional","descriptive","descriptions","captioning","representation","description","described","comparable","considerably","statistics","generating","interesting","constraint","approaches","exponential","theoretical","graphical","computational","representational","complexity","inference","importance","perspective","limitations","probabilistic","empirical","advantages","surveillance","candidate","benchmark","significant","intriguingly","improvement","specifically","techniques","commercial","detection","developed","localization","particular","multiagent","functions","traditional","collaborative","processes","continuous","structure","formulated","arguments","naturally","approximate","discretization","potential","approximation","formulate","adequately","efficiently","represented","variables","promising","systematically","literature","furthermore","retrieval","increasing","challenging","incidents","irrelevant","important","infringement","addressed","evaluated","densities","homomorphism","expensive","autoimmune","intuitive","guarantee","computable","theoretically","distinguish","competitive","difficult","subgraphs","classifier","projection","intermittent","aggregation","decomposition","significantly","characterisation","individuals","groupings","components","transient","appropriate","characterized","synthetically","correspond","decreases","motivated","outperforms","individual","aggregate","decomposed","populations","increases","numerical","intrinsic","effectiveness","extremely","represent","extraction","exemplified","frequency","particularly","functional","penalized","simulated","inappropriately","selecting","likelihood","unsatisfactory","parameters","afterward","application","regression","practical","regressions","simultaneously","maximization","initialization","performed","estimation","selection","expectation","polynomial","retrieving","robustness","estimated","partition","unfortunately","investigate","sequential","inherently","suggestions","phenomenon","shortcomings","underperforms","extensive","recurrent","propagation","parallelization","truncated","consistency","architecture","procedures","predictors","principle","prediction","res ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	inappropriately
# 	intimately
# 	transposable
# 	nonparametrically
# 	amortized
# 	distilling
# 	omnipresent
# 	ultrametric
# 	divisible
# 	textitnot
# 	parameterizations
# 	homoscedastic
# 	stochastically
# 	submodularity
# 	nonparametrics
# 	whitening
# 	detectability
# 	staleness
# 	synthesise
# 	nesterovs
# Some words which never appear in Statistics papers:
# 	responsive
# 	multiagent
# 	infringement
# 	homomorphism
# 	synthetically
# 	exemplified
# 	suggestions
# 	isolating
# 	silhouettes
# 	manipulation
# 	animation
# 	animations
# 	misspellings
# 	typographical
# 	levenshtein
# 	insertion
# 	httpsgithubcomhezhangsprinter
# 	downsampling
# 	upsampling
# 	obligation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0867055591567124e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
